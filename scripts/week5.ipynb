# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.array([1, 2, 3, 4, 5])

y = np.array([2, 4, 6, 9, 10])

m, b = np.polyfit(x, y, 1)

# %%
# plt.scatter(x, y, label= "y=2x", color="blue")
# plt.plot(x, m * x + b)
# plt.show()

# %%
ice_cream = pd.read_csv('../datasets/icecream.csv')
ice_cream
x = ice_cream["Temperature"]
y = ice_cream["Revenue"]

plt.scatter(x, y, label = "Increased Temperatures Correlate with Higher Ice Cream Revenue", color = "blue")
m, b = np.polyfit(x, y, 1)

plt.plot(x, m * x + b, color = "red")
